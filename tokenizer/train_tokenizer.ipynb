# %% [markdown]
# ### Training Data for Multilingual BPE Tokenizer
#
# Language distribution in the training corpus used to build the tokenizer:
#
# | Language/Script | Percentage |
# |----------------|------------|
# | English        | 60%        |
# | Hindi (Deva)   | 10%        |
# | Hindi (Latn)   | 10%        |
# | Kannada (Knda) | 10%        |
# | Kannada (Latn) | 10%        |

# %%
from datasets import load_dataset, load_from_disk
import random
import os

# Load a subset of a dataset and cache it locally
def download_dataset_and_load_subset(dataset_name, name=None, data_dir=None, split="train", num_rows=1000, save_dir="/home/yaseen/hf_datasets"):
    # Create a directory path that includes the dataset name and split
    dataset_path = dataset_name.replace('/', '_')
    save_path = os.path.join(save_dir, f"{dataset_path}_{split}")
    
    try:
        dataset = load_from_disk(save_path)
        print(f"Dataset {dataset_name} loaded from {save_path}..")
    
    except FileNotFoundError:
        # Load the dataset and cache it in the specified directory
        dataset = load_dataset(
            dataset_name, 
            name=name, 
            data_dir=data_dir, 
            split=split
        )
        
        # Ensure the base save directory exists
        os.makedirs(save_dir, exist_ok=True)
        
        # Save the dataset to disk
        dataset.save_to_disk(save_path)
        print(f"Dataset {dataset_name} saved to {save_path}..")
    
    # Select a random subset of the dataset
    indices = list(range(len(dataset)))
    random.shuffle(indices)
    selected_indices = indices[:num_rows]
    return dataset.select(selected_indices)

# Load subsets of each dataset with caching
dataset_en = download_dataset_and_load_subset("HuggingFaceFW/fineweb-edu", name="sample-10BT", num_rows=60_000)
dataset_hin_deva = download_dataset_and_load_subset("ai4bharat/sangraha", data_dir="synthetic/hin_Deva", num_rows=10_000)
dataset_hin_latn = download_dataset_and_load_subset("ai4bharat/sangraha", data_dir="synthetic/hin_Latn", num_rows=10_000)
dataset_kan_knda = download_dataset_and_load_subset("ai4bharat/sangraha", data_dir="synthetic/kan_Knda", num_rows=10_000)
dataset_kan_latn = download_dataset_and_load_subset("ai4bharat/sangraha", data_dir="synthetic/kan_Latn", num_rows=10_000)

# Print the first row of each subset to verify
print(dataset_en[0])
print(dataset_hin_deva[0])
print(dataset_hin_latn[0])
print(dataset_kan_knda[0])
print(dataset_kan_latn[0])
# Out:
# Loading dataset from disk:   0%|          | 0/99 [00:00<?, ?it/s]
# Dataset HuggingFaceFW/fineweb-edu loaded from /home/yaseen/hf_datasets/HuggingFaceFW_fineweb-edu_train..
# Loading dataset from disk:   0%|          | 0/43 [00:00<?, ?it/s]
# Dataset ai4bharat/sangraha loaded from /home/yaseen/hf_datasets/ai4bharat_sangraha_train..
# Loading dataset from disk:   0%|          | 0/43 [00:00<?, ?it/s]
# Dataset ai4bharat/sangraha loaded from /home/yaseen/hf_datasets/ai4bharat_sangraha_train..
# Loading dataset from disk:   0%|          | 0/43 [00:00<?, ?it/s]
# Dataset ai4bharat/sangraha loaded from /home/yaseen/hf_datasets/ai4bharat_sangraha_train..
# Loading dataset from disk:   0%|          | 0/43 [00:00<?, ?it/s]
# Dataset ai4bharat/sangraha loaded from /home/yaseen/hf_datasets/ai4bharat_sangraha_train..
# {'text': "Acids and alkalis\nSome pure acids include the hydroxides of: sodium, potassium and calcium\nAcids + Alkali --> salt + water\nHydrochloric acid + metal --> metal chloride + hydrogen\nHydrochloric acid + metal oxide --> metal chloride + water\nHydrochloric acid + metal carbonate --> metal chloride + carbon dioxide + water\nLitmus paper, universal indicator and PH meters detect acidity and alkalinity. Universal indicator and PhH meters measure PH.\nAcidic compounds produce aqueous hydrogen ions, H+(aq), when they dissolve in water. Alkaline compounds produce aqueous hydroxide ions, OH–(aq), when they dissolve in water. During a neutrilisation reactions these react to create water.\nRates of reaction\nScientists need to research rates of differnt reaction because a reaction occuring too quickly can be hazzardous and areaction occuring too slowly is not practical\nRate of reaction= The quanitity of product produced in a fixed time\nHow can we measure rate of reaction?\n- to collect and measure a gas product the gas should be sent along a tube into a water filled measuring cylinder (in a water bath) and the volume should be recoreded at regular intervals\n- you could put cotton wool over the conicle flask so that only gas escapes, place in on measuring sacles and record the mass at regular intervals\n- you could mix the solid and solution in the flask and start the timer, stop when you can no longer see the solid\n- to a reaction that produces an insoluble solid. Place the conicle flask on an X. Mix the olutions in the flask and start the timer, stop it when you can no longer see the X\nIt's imporant to control the rate of reaction because a reaction needs to be safe and cost effective\nwhat effects the rate of reaction\nSurface area- as surface area increases there are more particles exposed to the solutions so the chances of a collision increases.\nTempersture- as temperature increases the particles gain more energy so they move fastr and the chances of a collision increases\nConcentration- if there is a higher concentration of particles there is a higher chance that they will collide\nWe need chemicals to provide us with: food adictivea, fertilisers, dye, paints, pigments and pharmaceuticles\nPure acidic compunds that are solid include; citric and tartaric, that are liquid include; sulphuric, nitric and ethanoic, that are gases include; hydrogen chloride\nWhen we react acids and alkalis this is called chemical synthesis. The stages that are envolved with this are:\n- Choosing the reactant or the series of reactions that make the required product\n- Carrying out the rick assessment\n- Working out the quantaties of reactants to use\n- Carrying out the reaction with suitable appratus in the right conditions (such as temperature, concentration\n- Seperating the product from the reactant mixture (such as filtering)\n- Purifying the product (such as evaporation, crystallination, drying in an oven or in a desiccator) It is important the product is pure because the smallest impurty could cause harm eg. in a phamaceutical drug. This can be done through titrations\nEndothermic and Exothermic reactions\nIn a reaction bonds are broken releasing energy and bonds are formed absorbing energy.\nin a endothermic reaction more energy is envolded to form bonds than to break them so energy is absorbed from the surroundings.\nWhere as, in an exothermic reaction more energy is needed to break the bonds than to form them so energy is released into the environment (usually as heat energy)\nCalculating percentage yeild\nPercentage yield = actual yield∕predicted yield × 100\nFor example, if the predicted yield is 20 g but the actual yield is 15 g:\nPercentage yield = 15∕20 × 100 = 75%\nWhy the percentage yield of a product may be less than 100%:\n- Transferring liquids\n- Not all reactants react to make product\nIndustrial processes want a high percentage yeild because it reduces the waste of the reactants and the cost of the process\nMeasure y ...
# %%
# Concatenate all texts into a single list
all_texts = []

# Collect texts from each dataset
en_texts = [doc["text"].strip().replace("\n", " ") for doc in dataset_en]
hin_deva_texts = [doc["text"].strip().replace("\n", " ") for doc in dataset_hin_deva]
hin_latn_texts = [doc["text"].strip().replace("\n", " ") for doc in dataset_hin_latn]
kan_knda_texts = [doc["text"].strip().replace("\n", " ") for doc in dataset_kan_knda]
kan_latn_texts = [doc["text"].strip().replace("\n", " ") for doc in dataset_kan_latn]

# Add all texts to a single list
all_texts.extend(en_texts)
all_texts.extend(hin_deva_texts)
all_texts.extend(hin_latn_texts)
all_texts.extend(kan_knda_texts)
all_texts.extend(kan_latn_texts)

# Shuffle the combined texts
random.shuffle(all_texts)

print(f"Total number of texts: {len(all_texts)}")
print("\nFirst few texts after random shuffling:")
print(all_texts[:3])

corpus = "\n".join(all_texts)

# Save the combined texts to a file
with open("tok_corpus_large.txt", "w", encoding="utf-8") as file:
    file.write(corpus)
# Out:
# Total number of texts: 100000
#
# First few texts after random shuffling:
# ['grogo martic  graa athawa mait martic endoo kareyalpaduva frago martic (1822-30 august 1905), bosna srebrenada franciscan praantyada bosnian croat frear mattu barahagararagiddaru. jivanacharitre. martic ottoman saamraajyada bosniyaada kannina reppeya posuje baliya rastovasca gramadalli janisidaru. aata jhagreb mattu kitagalalli sikshana padedaru mattu 1844rahra chrismus dinadandu deekshe padedaru. aata cresovo mattu osovaadalli mooru varshagala kaala seve sallisidaru. sallisidaru 1851rinda aata sarajevodalli paadriyaagi seve sallisidaru. franciscan praantyada bosna srebrenada sanyaasiyaagi, martic tanna jeevanada bahupalu seve sallisidaru mattu franciscan mathadalliddaaga tanna hecchina kelasavannu nadesidaru. kresovodalli catherine. tanna youvanadalli, hecchu madhyama drashtikonakke badalaaguva modalu, raashtriyavaadi mattu romanticist aagi avaru illrian chalavaliya bembaligaraagiddaru.  martic barahagara mattu bhashantarakararagi kelasa maadidaru, homour mattu gothe krutigalannu croatian bhaashege bhashantarisidaru. bosnia mattu harjegovinaadalli austro-hangerian aakramanada samayadalli, avaru bosnia mattu harjegovina catholicgala paravagi raajakiyavaagi sakriyaraagiddaru. prabhaavagalu mattu parampare. aata aata kresevodalli ondu shaaleyannu mattu saarajevodalli ondu vyayaamashaaleyannu praarambhisidaru. ottoman aadalitada viruddhada horaatada mahakavyavada "osvetnichi" aatana atyanta prasiddha sahitya krutiyagittu. martic avaru albanian samskrutigoo kodugegalannu niididaru, yuva albanian barahagara gerge fishta avara mele prabhaava beeridaru, avaru kresovoda franciscan shaalegalige haajaraagiddaru, allie avaru martic mattu krotiyana barahagara sylviz stramir crangevic avarannu bhetiyaadaru, avaru aaa samayadalli bosniyaadalli vaasisuttiddaru.', "Women's health: Screening plays key role in reducing colon cancer deaths Studies consistently show that women are more likely than men to comply with screening recommendations. In addition, women are also more likely to report worrisome symptoms for evaluation. Despite what appears to be greater vigilance, however, women and men remain almost equally affected by colorectal cancer. In 2009, the most recent year numbers are available from the federal government’s Centers for Disease Control and Prevention, 136,717 people in the United States were diagnosed with colorectal cancer, including 70,223 men and 66,494 women. In the United States, 51,848 people died from colorectal cancer, including 26,806 men and 25,042 women. Preventing death from colon cancer takes two forms: screening of individuals with no symptoms and prompt evaluation of worrisome signs and symptoms. According to the CDC, “Of cancers that affect both men and women, colorectal cancer is the second leading cancer killer in the United States, but it doesn’t have to be. If everybody aged 50 or older had regular screening tests,screening tests, as many as 60 percent of deaths from colorectal cancer could be prevented. About nine out of every 10 people whose colorectal cancer is found early and treated are still alive five years later.” Despite this, nationwide, more than one-third of individuals eligible for screening do not get screened for colorectal cancer. What are the barriers to screening? Studies show the barriers to testing include cost, logistics, embarrassment and fear of discomfort related to colon cancer screening tests, and belief that one is not at risk. Studies also show that compliance improves when patients discuss with their physician both the individual risk of cancer and concerns regarding testing. Who should get screened? Anyone over age 50 should be screened for colon cancer. Screening may be recommended earlier than age 50 in individuals with a family history of colon cancer or polyps or a personal history of digestive problems. How do I get screened? There are many different screening tests available, including tests of the stool, X-ray tests, and a procedure called a colonoscopy that allows any p ...

# %% [markdown]
# ### Tokenizer Object Training

# %% [markdown]
# run train_tokenizer.py in tmux with custom environment
#
# ```bash
# tmux new -s train_tokenizer
# source *path_to_venv*/bin/activate
# python train_tokenizer.py
# ```

# %% [markdown]
# ### Tokenizer Object Testing

# %%
def test_encoding(tokenizer, text, allowed_special={"<|endoftext|>"}):
    print(f"Text: {text}")
    test_ids = tokenizer.encode(text, verbose=True, allowed_special=allowed_special)
    print("")
    print(f"Unmerged length: {len(text.encode('utf-8'))}")
    print(f"Merged length: {len(test_ids)}")
    print("-"*50)

# %%
tests = [
    "आज तो बहुत थक गया हूँ, ಸ್ವಲ್ಪ विश्रಾಂತಿ ಬೇಕು।",
    "मौसम कितना अच्छा है! ನೀವೂ ಹೊರಗೆ ಬನ್ನಿ, let's enjoy together.",
    "स्वल्पा adjust करो, बैंगलोर का ट्रैफिक ऐसा ही है।",
    "ನೀವು ಚಹಾ ಕುಡಿತೀರಾ? मुझे एक cup चाहिए।",
    "आज का काम पूरा करो, ನಾಳೆ ಎಲ್ಲಿಂದ ಆರಂಭಿಸೋದು ನೋಡಿ।",
    "ಪಾರ್ಟಿ ಹೇಗೆ ಇತ್ತು? मुझे तो बहुत मजा आया!",
    "ನಮ್ಮ ಚೂರು ಸಹನಶೀಲತೆಯನ್ನು ತೋರಿಸಿ, ये थोड़ी देर का मसला है।",
    "ಸಮಯ ನಿಲ್ಲುತ್ತಿಲ್ಲ, जिंदगी में स्वल्पा मज़ा भी जरूरी है।",
    "My name is Yaseen, and I'm a software engineer.<|endoftext|>"
]

for test in tests:
    test_encoding(tokenizer, test)
